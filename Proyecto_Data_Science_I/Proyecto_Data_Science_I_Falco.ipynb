# %% [markdown]
# <a href="https://colab.research.google.com/github/Lautaro-Falco/Portfolio-Data-Science/blob/main/Proyecto_Data_Science_I_Falco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto Data Science I**

# %% [markdown]
# ## **¿De qué factores depende el riesgo de desercion de un estudiante universitario?**
#
#
#
#
#
#
#
#
# ![endless_6w9u25s2hS1U9L0HEN.png](data:image/png;base64,...)

# %% [markdown]
# ## ✳️ Estudiante: Lautaro Falco
#
# ### 🧠 Problemática:
# En el ámbito universitario, la deserción estudiantil representa un desafío crítico tanto para las instituciones educativas como para los propios estudiantes. Identificar a tiempo los factores que aumentan el riesgo de abandono puede ser clave para implementar estrategias de prevención y acompañamiento. El objetivo principal de este análisis es descubrir qué variables se relacionan con el **riesgo de deserción**, con el fin de generar conocimientos que ayuden a mejorar la permanencia en los estudios superiores.
#
# ### 📌 Tema a tratar:
# Este proyecto se basa en el análisis de un dataset con información de 80.000 estudiantes, que incluye variables relacionadas con hábitos de estudio, motivación, estrés, salud mental, rendimiento académico, entre otras. A partir de estos datos, se busca detectar patrones que expliquen por qué algunos estudiantes presentan un mayor riesgo de abandonar la carrera, para así orientar posibles intervenciones educativas basadas en evidencia.
#
# ### 📎 Fuente de datos:
# https://www.kaggle.com/datasets/aryan208/student-habits-and-academic-performance-dataset/data
#
# ---
#
# ### 📋 DESCRIPCIÓN DE LAS VARIABLES Y TIPOS DE DATOS
# | Nombre original (inglés)        | Nombre en español             | Descripción                                                        | Tipo de dato |
# | ------------------------------- | ----------------------------- | ------------------------------------------------------------------ | ------------ |
# | `student_id`                    | `id_estudiante`               | ID único del estudiante                                            | int          |
# | `age`                           | `edad`                        | Edad del estudiante                                                | int          |
# | `gender`                        | `genero`                      | Género del estudiante (Masculino/Femenino/Otro)                    | str          |
# | `major`                         | `carrera`                     | Carrera que estudia el alumno                                      | str          |
# | `study_hours_per_day`           | `horas_estudio_dia`           | Horas dedicadas al estudio por día                                 | float        |
# | `social_media_hours`            | `horas_redes_sociales`        | Horas diarias en redes sociales                                    | float        |
# | `netflix_hours`                 | `horas_netflix`               | Horas diarias viendo Netflix u otras plataformas                   | float        |
# | `part_time_job`                 | `trabajo_medio_tiempo`        | Si trabaja medio tiempo (Sí/No)                                    | str          |
# | `attendance_percentage`         | `porcentaje_asistencia`       | Porcentaje de asistencia a clases                                  | float        |
# | `sleep_hours`                   | `horas_sueno`                 | Promedio de horas de sueño por noche                               | float        |
# | `diet_quality`                  | `calidad_dieta`               | Calidad de alimentación (Mala/Regular/Buena)                       | str          |
# | `exercise_frequency`            | `frecuencia_ejercicio`        | Frecuencia semanal de ejercicio                                    | int          |
# | `parental_education_level`      | `educacion_padres`            | Nivel educativo de los padres                                      | str          |
# | `internet_quality`              | `calidad_internet`            | Calidad del acceso a internet (Mala/Media/Buena)                   | str          |
# | `mental_health_rating`          | `salud_mental`                | Autoevaluación de salud mental (escala del 1 al 10)                | int          |
# | `extracurricular_participation` | `actividad_extracurricular`   | Participa en actividades extracurriculares (Sí/No)                 | str          |
# | `previous_gpa`                  | `promedio_anterior`           | GPA del período académico anterior                                 | float        |
# | `semester`                      | `semestre`                    | Semestre que cursa actualmente                                     | int          |
# | `stress_level`                  | `nivel_estres`                | Nivel de estrés percibido (escala del 1 al 10)                     | float        |
# | `dropout_risk`                  | `riesgo_desercion`            | Riesgo de abandonar los estudios (Alto/Medio/Bajo)                 | str          |
# | `social_activity`               | `actividad_social`            | Frecuencia semanal de actividades sociales                         | int          |
# | `screen_time`                   | `tiempo_pantalla`             | Tiempo total diario frente a pantallas                             | float        |
# | `study_environment`             | `ambiente_estudio`            | Tipo de ambiente donde estudia (Silencioso/Ruidoso/etc.)           | str          |
# | `access_to_tutoring`            | `acceso_tutoria`              | Tiene acceso a tutorías académicas (Sí/No)                         | str          |
# | `family_income_range`           | `ingreso_familiar`            | Rango de ingresos familiares (Bajo/Medio/Alto)                     | str          |
# | `parental_support_level`        | `apoyo_parental`              | Nivel de apoyo recibido de los padres (escala 1–10)                | int          |
# | `motivation_level`              | `nivel_motivacion`            | Nivel de motivación académica (escala 1–10)                        | int          |
# | `exam_anxiety_score`            | `nivel_ansiedad`             | Nivel de ansiedad ante exámenes (escala 1–10)                      | int          |
# | `learning_style`                | `estilo_aprendizaje`          | Estilo de aprendizaje (Visual/Auditivo/Kinestésico)                | str          |
# | `time_management_score`         | `gestion_tiempo`              | Habilidad para gestionar el tiempo (escala del 1 al 10)            | float        |
# | `exam_score`                    | `puntaje_examen`              | Puntaje obtenido en el examen final                                | int          |

# %% [markdown]
# ## 📚 Librerías utilizadas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 📁 Acceso al dataset
#
# El archivo de datos utilizado para este proyecto (`enhanced_student_habits_performance_dataset.csv`) se encuentra alojado en una carpeta compartida de Google Drive junto al notebook de Google Colab utilizado para el desarrollo del trabajo:
#
# 📂 Carpeta del proyecto: `Proyecto_Data_Science_I_Falco`
#
# 📌 El acceso a ambos archivos (notebook y dataset) se encuentra habilitado para revisión mediante el siguiente enlace:
# https://drive.google.com/drive/u/0/folders/1xbukoaN5z7oQMPRL6KDH97GZ-UCrTBb2
#
# ⚠️ Si se prefiere ejecutar el notebook desde otro entorno, puede ser necesario montar Drive con `from google.colab import drive` y ajustar la ruta del archivo según corresponda.

# %%
df_habits = pd.read_csv('/content/drive/MyDrive/Proyecto_Data_Science_I_Falco/enhanced_student_habits_performance_dataset.csv', delimiter=',') #Cargo el set de datos

# %% [markdown]
# ## 🔍 Análisis general del dataset
# - Dimensiones del dataset
# - Tipos de datos
# - Datos faltantes
# - Valores únicos por columna

# %%
df_habits.head(100) #Reviso las 100 primeras filas
# Out:
#     student_id  age  gender             major  study_hours_per_day  \
# 0       100000   26    Male  Computer Science             7.645367
# 1       100001   28    Male              Arts             5.700000
# 2       100002   17    Male              Arts             2.400000
# 3       100003   27   Other        Psychology             3.400000
# 4       100004   25  Female          Business             4.700000
# ..         ...  ...     ...               ...                  ...
# 95      100095   26    Male           Biology             5.800000
# 96      100096   27  Female           Biology             6.100000
# 97      100097   26   Other  Computer Science             2.402845
# 98      100098   26  Female           Biology             1.100000
# 99      100099   16    Male       Engineering             5.600000
#
#     social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# 0                  3.0            0.1           Yes                   70.3
# 1                  0.5            0.4            No                   88.4
# 2                  4.2            0.7            No                   82.1
# 3                  4.6            2.3           Yes                   79.3
# 4                  0.8            2.7           Yes                   62.9
# ..                 ...            ...           ...                    ...
# 95                 0.3            0.6           Yes                   62.4
# 96                 1.2            2.5           Yes                   56.0
# 97                 0.4            3.4            No                   74.0
# 98                 3.6            1.6           Yes                   73.8
# 99                 5.0            2.0           Yes                   65.9
#
#     sleep_hours  ... screen_time  study_environment access_to_tutoring  \
# 0           6.2  ...        10.9  Co-Learning Group                Yes
# 1           7.2  ...         8.3  Co-Learning Group                Yes
# 2           9.2  ...         8.0            Library                Yes
# 3           4.2  ...        11.7  Co-Learning Group                Yes
# 4           6.5  ...         9.4         Quiet Room                Yes
# ..          ...  ...         ...                ...                ...
# 95          8.7  ...         7.1  Co-Learning Group                Yes
# 96          5.8  ...        10.3            Library                Yes
# 97          4.4  ...         7.5  Co-Learning Group                 No
# 98          7.3  ...         6.5            Library                Yes
# 99          7.9  ...        13.3         Quiet Room                 No
#
#    family_income_range  parental_support_level motivation_level  \
# 0                 High                       9                7
# 1                  Low                       7                2
# 2                 High                       3                9
# 3                  Low                       5                3
# 4               Medium                       9                1
# ..                 ...                     ...              ...
# 95              Medium                       8                1
# 96              Medium                       8               10
# 97                High                       1                4
# 98                High                       9                6
# 99                 Low                      10                5
#
#     exam_anxiety_score  learning_style  time_management_score exam_score
# 0                    8         Reading                    3.0        100
# 1                   10         Reading                    6.0         99
# 2                    6     Kinesthetic                    7.6         98
# 3                   10         Reading                    3.2        100
# 4                   10         Reading                    7.1         98
# ..                 ...             ...                    ...        ...
# 95                  10     Kinesthetic                    1.1         84
# 96                   5         Reading                    3.2         97
# 97                  10     Kinesthetic                    2.9         72
# 98                   9          Visual                    4.5         88
# 99                  10          Visual                    8.2         92
#
# [100 rows x 31 columns]

# %%
print('Shape del dataset:', df_habits.shape) #Reviso cantidad de filas y columnas
print('\nTipos de datos:')
print(df_habits.dtypes) #Reviso el tipo de dato de las columnas
# Out:
# Shape del dataset: (80000, 31)
#
# Tipos de datos:
# student_id                         int64
# age                                int64
# gender                            object
# major                             object
# study_hours_per_day              float64
# social_media_hours               float64
# netflix_hours                    float64
# part_time_job                     object
# attendance_percentage            float64
# sleep_hours                      float64
# diet_quality                      object
# exercise_frequency                 int64
# parental_education_level          object
# internet_quality                  object
# mental_health_rating             float64
# extracurricular_participation     object
# previous_gpa                     float64
# semester                           int64
# stress_level                     float64
# dropout_risk                      object
# social_activity                    int64
# screen_time                      float64
# study_environment                 object
# access_to_tutoring                object
# family_income_range               object
# parental_support_level             int64
# motivation_level                   int64
# exam_anxiety_score                 int64
# learning_style                    object
# time_management_score            float64
# exam_score                         int64
# dtype: object

# %%
df_habits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     80000 non-null  int64
#  1   age                            80000 non-null  int64
#  2   gender                         80000 non-null  object
#  3   major                          80000 non-null  object
#  4   study_hours_per_day            80000 non-null  float64
#  5   social_media_hours             80000 non-null  float64
#  6   netflix_hours                  80000 non-null  float64
#  7   part_time_job                  80000 non-null  object
#  8   attendance_percentage          80000 non-null  float64
#  9   sleep_hours                    80000 non-null  float64
#  10  diet_quality                   80000 non-null  object
#  11  exercise_frequency             80000 non-null  int64
#  12  parental_education_level       80000 non-null  object
#  13  internet_quality               80000 non-null  object
#  14  mental_health_rating           80000 non-null  float64
#  15  extracurricular_participation  80000 non-null  object
#  16  previous_gpa                   80000 non-null  float64
#  17  semester                       80000 non-null  int64
#  18  stress_level                   80000 non-null  float64
#  19  dropout_risk                   80000 non-null  object
#  20  social_activity                80000 non-null  int64
#  21  screen_time                    80000 non-null  float64
#  22  study_environment              80000 non-null  object
#  23  access_to_tutoring             80000 non-null  object
#  24  family_income_range            80000 non-null  object
#  25  parental_support_level         80000 non-null  int64
#  26  motivation_level               80000 non-null  int64
#  27  exam_anxiety_score             80000 non-null  int64
#  28  learning_style                 80000 non-null  object
#  29  time_management_score          80000 non-null  float64
#  30  exam_score                     80000 non-null  int64
# dtypes: float64(10), int64(9), object(12)
# memory usage: 18.9+ MB

# %%
df_habits.select_dtypes(include=['int64', 'float64']).describe() #Hago una revision estadistica rapida de las columnas numericas
# Out:
#           student_id           age  study_hours_per_day  social_media_hours  \
# count   80000.000000  80000.000000         80000.000000        80000.000000
# mean   139999.500000     22.004288             4.174388            2.501366
# std     23094.155105      3.745570             2.004135            1.445441
# min    100000.000000     16.000000             0.000000            0.000000
# 25%    119999.750000     19.000000             2.800000            1.200000
# 50%    139999.500000     22.000000             4.125624            2.500000
# 75%    159999.250000     25.000000             5.500000            3.800000
# max    179999.000000     28.000000            12.000000            5.000000
#
#        netflix_hours  attendance_percentage   sleep_hours  exercise_frequency  \
# count   80000.000000           80000.000000  80000.000000        80000.000000
# mean        1.997754              69.967884      7.017417            3.516587
# std         1.155992              17.333015      1.467377            2.291575
# min         0.000000              40.000000      4.000000            0.000000
# 25%         1.000000              55.000000      6.000000            2.000000
# 50%         2.000000              69.900000      7.000000            4.000000
# 75%         3.000000              84.900000      8.000000            6.000000
# max         4.000000             100.000000     12.000000            7.000000
#
#        mental_health_rating  previous_gpa      semester  stress_level  \
# count          80000.000000  80000.000000  80000.000000  80000.000000
# mean               6.804107      3.602448      4.497338      5.012478
# std                1.921579      0.462876      2.295312      1.953174
# min                1.000000      1.640000      1.000000      1.000000
# 25%                5.500000      3.270000      2.000000      3.600000
# 50%                6.900000      3.790000      5.000000      5.000000
# 75%                8.200000      4.000000      7.000000      6.400000
# max               10.000000      4.000000      8.000000     10.000000
#
#        social_activity   screen_time  parental_support_level  \
# count     80000.000000  80000.000000            80000.000000
# mean          2.500225      9.673029                5.479438
# std           1.704292      2.780869                2.873327
# min           0.000000      0.300000                1.000000
# 25%           1.000000      7.800000                3.000000
# 50%           2.000000      9.700000                5.000000
# 75%           4.000000     11.600000                8.000000
# max           5.000000     21.000000               10.000000
#
#        motivation_level  exam_anxiety_score  time_management_score  \
# count      80000.000000        80000.000000           80000.000000
# mean           5.488525            8.508475               5.499132
# std            2.867782            1.796411               2.603534
# min            1.000000            5.000000               1.000000
# 25%            3.000000            7.000000               3.200000
# 50%            5.000000           10.000000               5.500000
# 75%            8.000000           10.000000               7.800000
# max           10.000000           10.000000              10.000000
#
#          exam_score
# count  80000.000000
# mean      89.141350
# std       11.591497
# min       36.000000
# 25%       82.000000
# 50%       93.000000
# 75%      100.000000
# max      100.000000

# %% [markdown]
# ### 🔎 Análisis de posibles outliers
#
# Se utilizó la función `.describe()` sobre las variables numéricas del dataset para observar estadísticos clave como el mínimo, máximo y los cuartiles. A partir de esta revisión, no se detectaron valores imposibles o claramente erróneos (por ejemplo, más de 24 horas por día o promedios mayores a 10).
#
# Si bien algunas observaciones presentan valores altos o bajos dentro de lo esperable (como estudiantes con más de 10 horas de estudio diario), se consideraron casos plausibles en el contexto académico. Por lo tanto, no se aplicó eliminación de outliers, y se optó por conservar la información original en pos de preservar la variabilidad del dataset.

# %%
df_habits.describe(include=['object']) #Hago una revision estadistica rapida de las columnas no numericas
# Out:
#         gender  major part_time_job diet_quality parental_education_level  \
# count    80000  80000         80000        80000                    80000
# unique       3      6             2            3                        5
# top     Female   Arts            No         Good             Some College
# freq     26705  13505         40195        39935                    16115
#
#        internet_quality extracurricular_participation dropout_risk  \
# count             80000                         80000        80000
# unique                3                             2            2
# top                High                            No           No
# freq              26749                         40058        78418
#
#        study_environment access_to_tutoring family_income_range learning_style
# count              80000              80000               80000          80000
# unique                 5                  2                   3              4
# top                 Dorm                 No                 Low    Kinesthetic
# freq               16119              40039               26720          20143

# %% [markdown]
# ### 🔍 Exploración inicial del dataset
#
# Para comenzar, se realizó una revisión general del dataset con el fin de entender su estructura, dimensiones y tipos de datos. Esta etapa incluyó:
#
# - Visualización de las primeras 100 filas para familiarizarse con el contenido.
# - Verificación de la **cantidad de filas y columnas** mediante `.shape`.
# - Análisis de los **tipos de datos** con `.dtypes` y `.info()` para detectar posibles conversiones necesarias o columnas irrelevantes.
# - Revisión estadística básica de las **columnas numéricas** con `.describe()` para observar la distribución, valores extremos y rangos.
# - Análisis de las **columnas categóricas** para conocer la cantidad de categorías y su distribución general.
#
# Este análisis permitió identificar desde el inicio que el dataset estaba limpio (sin valores nulos ni duplicados), lo cual facilitó las siguientes etapas del proceso.

# %% [markdown]
# ## 🧹 Limpieza de datos
# - Eliminación de duplicados
# - Tratamiento de valores nulos
# - Corrección de formatos
# - Redondeo de decimales innecesarios

# %%
#Traduciendo columnas de nuestro set de datos
df_habits = df_habits.rename(columns={
    "student_id": "id_estudiante",
    "age": "edad",
    "gender": "genero",
    "major": "carrera",
    "study_hours_per_day": "horas_estudio_dia",
    "social_media_hours": "horas_redes_sociales",
    "netflix_hours": "horas_netflix",
    "part_time_job": "trabajo_medio_tiempo",
    "attendance_percentage": "porcentaje_asistencia",
    "sleep_hours": "horas_sueno",
    "diet_quality": "calidad_dieta",
    "exercise_frequency": "frecuencia_ejercicio",
    "parental_education_level": "educacion_padres",
    "internet_quality": "calidad_internet",
    "mental_health_rating": "salud_mental",
    "extracurricular_participation": "actividad_extracurricular",
    "previous_gpa": "promedio_anterior",
    "semester": "semestre",
    "stress_level": "nivel_estres",
    "dropout_risk": "riesgo_desercion",
    "social_activity": "actividad_social",
    "screen_time": "tiempo_pantalla",
    "study_environment": "ambiente_estudio",
    "access_to_tutoring": "acceso_tutoria",
    "family_income_range": "ingreso_familiar",
    "parental_support_level": "apoyo_parental",
    "motivation_level": "nivel_motivacion",
    "exam_anxiety_score": "nivel_ansiedad",
    "learning_style": "estilo_aprendizaje",
    "time_management_score": "gestion_tiempo",
    "exam_score": "puntaje_examen"
})
df_habits
# Out:
#        id_estudiante  edad  genero           carrera  horas_estudio_dia  \
# 0             100000    26    Male  Computer Science           7.645367
# 1             100001    28    Male              Arts           5.700000
# 2             100002    17    Male              Arts           2.400000
# 3             100003    27   Other        Psychology           3.400000
# 4             100004    25  Female          Business           4.700000
# ...              ...   ...     ...               ...                ...
# 79995         179995    16    Male       Engineering           3.700000
# 79996         179996    16  Female          Business           1.200000
# 79997         179997    26  Female              Arts           4.100000
# 79998         179998    23   Other           Biology           3.800000
# 79999         179999    25   Other       Engineering           3.000000
#
#        horas_redes_sociales  horas_netflix trabajo_medio_tiempo  \
# 0                       3.0            0.1                  Yes
# 1                       0.5            0.4                   No
# 2                       4.2            0.7                   No
# 3                       4.6            2.3                  Yes
# 4                       0.8            2.7                  Yes
# ...                     ...            ...                  ...
# 79995                   2.1            1.0                  Yes
# 79996                   0.4            2.9                   No
# 79997                   1.6            1.6                  Yes
# 79998                   0.6            3.5                  Yes
# 79999                   4.5            3.4                  Yes
#
#        porcentaje_asistencia  horas_sueno  ... tiempo_pantalla  \
# 0                       70.3          6.2  ...            10.9
# 1                       88.4          7.2  ...             8.3
# 2                       82.1          9.2  ...             8.0
# 3                       79.3          4.2  ...            11.7
# 4                       62.9          6.5  ...             9.4
# ...                      ...          ...  ...             ...
# 79995                   80.8          6.1  ...             8.3
# 79996                   99.5          4.1  ...             4.7
# 79997                   46.1          8.3  ...             7.5
# 79998                   58.7          5.8  ...             9.3
# 79999                   97.7          5.3  ...            12.2
#
#         ambiente_estudio acceso_tutoria ingreso_familiar  apoyo_parental  \
# 0      Co-Learning Group            Yes             High               9
# 1      Co-Learning Group            Yes              Low               7
# 2                Library            Yes             High               3
# 3      Co-Learning Group            Yes              Low               5
# 4             Quiet Room            Yes           Medium               9
# ...                  ...            ...              ...             ...
# 79995            Library             No              Low               1
# 79996  Co-Learning Group             No              Low               3
# 79997               Dorm             No           Medium               7
# 79998         Quiet Room            Yes              Low               2
# 79999  Co-Learning Group            Yes           Medium               1
#
#       nivel_motivacion  nivel_ansiedad  estilo_aprendizaje  gestion_tiempo  \
# 0                    7               8             Reading             3.0
# 1                    2              10             Reading             6.0
# 2                    9               6         Kinesthetic             7.6
# 3                    3              10             Reading             3.2
# 4                    1              10             Reading             7.1
# ...                ...             ...                 ...             ...
# 79995                4              10            Auditory             5.3
# 79996                2              10         Kinesthetic             6.8
# 79997                1              10              Visual             1.3
# 79998                8               7         Kinesthetic             3.7
# 79999                8               7             Reading             6.7
#
#       puntaje_examen
# 0                100
# 1                 99
# 2                 98
# 3                100
# 4                 98
# ...              ...
# 79995             88
# 79996             52
# 79997             89
# 79998             96
# 79999            100
#
# [80000 rows x 31 columns]

# %%
print('Valores unicos:\n',df_habits.nunique()) #Reviso que cantidad de valores unicos tiene cada columna para visualizar posibles errores
# Out:
# Valores unicos:
#  id_estudiante                80000
# edad                            13
# genero                           3
# carrera                          6
# horas_estudio_dia            13364
# horas_redes_sociales            51
# horas_netflix                   41
# trabajo_medio_tiempo             2
# porcentaje_asistencia          601
# horas_sueno                     81
# calidad_dieta                    3
# frecuencia_ejercicio             8
# educacion_padres                 5
# calidad_internet                 3
# salud_mental                   100
# actividad_extracurricular        2
# promedio_anterior              220
# semestre                         8
# nivel_estres                    91
# riesgo_desercion                 2
# actividad_social                 6
# tiempo_pantalla                198
# ambiente_estudio                 5
# acceso_tutoria                   2
# ingreso_familiar                 3
# apoyo_parental                  10
# nivel_motivacion                10
# nivel_ansiedad                   6
# estilo_aprendizaje               4
# gestion_tiempo                  91
# puntaje_examen                  65
# dtype: int64

# %%
#Reviso valores como otros en genero para ver si lo saco del analisis
print(df_habits['genero'].unique())
print(df_habits['genero'].value_counts())
# Out:
# ['Male' 'Other' 'Female']
# genero
# Female    26705
# Male      26698
# Other     26597
# Name: count, dtype: int64

# %% [markdown]
# Se llega a la conclusion que los valores otros en genero son muchos como para sacarlos del analisis, decido tenerlos en cuenta en el analisis

# %%
print('Valores nulos:\n',df_habits.isna().sum()) #Reviso si tiene valores nulls o NaN
print('\nduplicados: ',df_habits.duplicated().sum()) #Reviso si cuenta con valores duplicados
# Out:
# Valores nulos:
#  id_estudiante                0
# edad                         0
# genero                       0
# carrera                      0
# horas_estudio_dia            0
# horas_redes_sociales         0
# horas_netflix                0
# trabajo_medio_tiempo         0
# porcentaje_asistencia        0
# horas_sueno                  0
# calidad_dieta                0
# frecuencia_ejercicio         0
# educacion_padres             0
# calidad_internet             0
# salud_mental                 0
# actividad_extracurricular    0
# promedio_anterior            0
# semestre                     0
# nivel_estres                 0
# riesgo_desercion             0
# actividad_social             0
# tiempo_pantalla              0
# ambiente_estudio             0
# acceso_tutoria               0
# ingreso_familiar             0
# apoyo_parental               0
# nivel_motivacion             0
# nivel_ansiedad               0
# estilo_aprendizaje           0
# gestion_tiempo               0
# puntaje_examen               0
# dtype: int64
#
# duplicados:  0

# %% [markdown]
# No tenemos valores nulls,NaN ni duplicados en nuestro set de datos

# %%
#Chequeamos que no haya valores insolitos como mas de 24 horas o muchas horas de sueño
df_habits.select_dtypes(include=['int64', 'float64']).describe() #Chequeo de valores insólitos o mal cargados
# Out:
#        id_estudiante          edad  horas_estudio_dia  horas_redes_sociales  \
# count   80000.000000  80000.000000       80000.000000          80000.000000
# mean   139999.500000     22.004288           4.174388              2.501366
# std     23094.155105      3.745570           2.004135              1.445441
# min    100000.000000     16.000000           0.000000              0.000000
# 25%    119999.750000     19.000000           2.800000              1.200000
# 50%    139999.500000     22.000000           4.125624              2.500000
# 75%    159999.250000     25.000000           5.500000              3.800000
# max    179999.000000     28.000000          12.000000              5.000000
#
#        horas_netflix  porcentaje_asistencia   horas_sueno  \
# count   80000.000000           80000.000000  80000.000000
# mean        1.997754              69.967884      7.017417
# std         1.155992              17.333015      1.467377
# min         0.000000              40.000000      4.000000
# 25%         1.000000              55.000000      6.000000
# 50%         2.000000              69.900000      7.000000
# 75%         3.000000              84.900000      8.000000
# max         4.000000             100.000000     12.000000
#
#        frecuencia_ejercicio  salud_mental  promedio_anterior      semestre  \
# count          80000.000000  80000.000000       80000.000000  80000.000000
# mean               3.516587      6.804107           3.602448      4.497338
# std                2.291575      1.921579           0.462876      2.295312
# min                0.000000      1.000000           1.640000      1.000000
# 25%                2.000000      5.500000           3.270000      2.000000
# 50%                4.000000      6.900000           3.790000      5.000000
# 75%                6.000000      8.200000           4.000000      7.000000
# max                7.000000     10.000000           4.000000      8.000000
#
#        nivel_estres  actividad_social  tiempo_pantalla  apoyo_parental  \
# count  80000.000000      80000.000000     80000.000000    80000.000000
# mean       5.012478          2.500225         9.673029        5.479438
# std        1.953174          1.704292         2.780869        2.873327
# min        1.000000          0.000000         0.300000        1.000000
# 25%        3.600000          1.000000         7.800000        3.000000
# 50%        5.000000          2.000000         9.700000        5.000000
# 75%        6.400000          4.000000        11.600000        8.000000
# max       10.000000          5.000000        21.000000       10.000000
#
#        nivel_motivacion  nivel_ansiedad  gestion_tiempo  puntaje_examen
# count      80000.000000    80000.000000    80000.000000    80000.000000
# mean           5.488525        8.508475        5.499132       89.141350
# std            2.867782        1.796411        2.603534       11.591497
# min            1.000000        5.000000        1.000000       36.000000
# 25%            3.000000        7.000000        3.200000       82.000000
# 50%            5.000000       10.000000        5.500000       93.000000
# 75%            8.000000       10.000000        7.800000      100.000000
# max           10.000000       10.000000       10.000000      100.000000

# %% [markdown]
# No se observan valores insolitos o mal cargados en nuestro set de datos

# %%
#Ver valores unicos columnas object para traducir
print(df_habits["educacion_padres"].unique())
print(df_habits["genero"].unique())
print(df_habits["carrera"].unique())
print(df_habits["calidad_dieta"].unique())
print(df_habits["calidad_internet"].unique())
print(df_habits["ambiente_estudio"].unique())
print(df_habits["ingreso_familiar"].unique())
print(df_habits["estilo_aprendizaje"].unique())
# Out:
# ['Some College' 'PhD' 'High School' 'Master' 'Bachelor']
# ['Male' 'Other' 'Female']
# ['Computer Science' 'Arts' 'Psychology' 'Business' 'Engineering' 'Biology']
# ['Poor' 'Good' 'Fair']
# ['High' 'Low' 'Medium']
# ['Co-Learning Group' 'Library' 'Quiet Room' 'Dorm' 'Cafe']
# ['High' 'Low' 'Medium']
# ['Reading' 'Kinesthetic' 'Visual' 'Auditory']

# %%
#Traduciendo filas de nuestro set de datos
df_habits['genero'] = df_habits['genero'].replace({
    'Male':'Masculino',
    'Female':'Femenino',
    'Other':'Otro'
})

df_habits["carrera"] = df_habits["carrera"].replace({
    "Arts": "Artes",
    "Psychology": "Psicologia",
    "Computer Science": "Ciencias de la Computacion",
    "Business": "Administracion",
    "Engineering": "Ingenieria",
    "Biology": "Biologia"
})

df_habits['trabajo_medio_tiempo'] = df_habits['trabajo_medio_tiempo'].replace({
    'Yes':'Si',
})

df_habits['riesgo_desercion'] = df_habits['riesgo_desercion'].replace({
    'Yes':'Si',
})

df_habits['ambiente_estudio'] = df_habits["ambiente_estudio"].replace({
    "Co-Learning Group": "Grupo de estudio colaborativo",
    "Library": "Biblioteca",
    "Quiet Room": "Sala silenciosa",
    "Dorm": "Dormitorio",
    "Cafe": "Cafetería"
})

df_habits['acceso_tutoria'] = df_habits['acceso_tutoria'].replace({
    'Yes':'Si',
})

df_habits['actividad_extracurricular'] = df_habits['actividad_extracurricular'].replace({
    'Yes':'Si',
})

df_habits["ingreso_familiar"] = df_habits["ingreso_familiar"].replace({
    "Low": "Bajo",
    "Medium": "Medio",
    "High": "Alto"
})

df_habits["estilo_aprendizaje"] = df_habits["estilo_aprendizaje"].replace({
    "Reading": "Lectura",
    "Kinesthetic": "Kinestésico",
    "Visual": "Visual",
    "Auditory": "Auditivo"
})

df_habits["calidad_dieta"] = df_habits["calidad_dieta"].replace({
    "Poor": "Mala",
    "Fair": "Aceptable",
    "Good": "Buena"
})

df_habits["calidad_internet"] = df_habits["calidad_internet"].replace({
    "Poor": "Mala",
    "Moderate": "Media",
    "High": "Buena"
})

df_habits["educacion_padres"] = df_habits["educacion_padres"].replace({
    "Some College": "Algunos estudios universitarios",
    "PhD": "Doctorado",
    "High School": "Escuela secundaria",
    "Master": "Maestría",
    "Bachelor": "Licenciatura"
})

df_habits.select_dtypes(include=['object'])
# Out:
#           genero                     carrera trabajo_medio_tiempo  \
# 0      Masculino  Ciencias de la Computacion                   Si
# 1      Masculino                       Artes                   No
# 2      Masculino                       Artes                   No
# 3           Otro                  Psicologia                   Si
# 4       Femenino              Administracion                   Si
# ...          ...                         ...                  ...
# 79995  Masculino                  Ingenieria                   Si
# 79996   Femenino              Administracion                   No
# 79997   Femenino                       Artes                   Si
# 79998       Otro                    Biologia                   Si
# 79999       Otro                  Ingenieria                   Si
#
#       calidad_dieta                 educacion_padres calidad_internet  \
# 0              Mala  Algunos estudios universitarios            Buena
# 1             Buena                        Doctorado              Low
# 2             Buena               Escuela secundaria              Low
# 3         Aceptable                         Maestría           Medium
# 4             Buena                        Doctorado              Low
# ...             ...                              ...              ...
# 79995     Aceptable               Escuela secundaria           Medium
# 79996         Buena  Algunos estudios universitarios              Low
# 79997         Buena                         Maestría              Low
# 79998         Buena                        Doctorado            Buena
# 79999     Aceptable  Algunos estudios universitarios            Buena
#
#       actividad_extracurricular riesgo_desercion  \
# 0                            Si               No
# 1                            No               No
# 2                            Si               No
# 3                            Si               No
# 4                            No               No
# ...                         ...              ...
# 79995                        No               No
# 79996                        Si               No
# 79997                        Si               No
# 79998                        Si               No
# 79999                        No               No
#
#                     ambiente_estudio acceso_tutoria ingreso_familiar  \
# 0      Grupo de estudio colaborativo             Si             Alto
# 1      Grupo de estudio colaborativo             Si             Bajo
# 2                         Biblioteca             Si             Alto
# 3      Grupo de estudio colaborativo             Si             Bajo
# 4                    Sala silenciosa             Si            Medio
# ...                              ...            ...              ...
# 79995                     Biblioteca             No             Bajo
# 79996  Grupo de estudio colaborativo             No             Bajo
# 79997                     Dormitorio             No            Medio
# 79998                Sala silenciosa             Si             Bajo
# 79999  Grupo de estudio colaborativo             Si            Medio
#
#       estilo_aprendizaje
# 0                Lectura
# 1                Lectura
# 2            Kinestésico
# 3                Lectura
# 4                Lectura
# ...                  ...
# 79995           Auditivo
# 79996        Kinestésico
# 79997             Visual
# 79998        Kinestésico
# 79999            Lectura
#
# [80000 rows x 12 columns]

# %%
#Normalizar cantidad de decimales en columnas de horas, porcentajes y puntajes, para luego analizar graficando.
cols_to_round = ['horas_estudio_dia', 'horas_redes_sociales', 'horas_netflix',
                 'horas_sueno', 'porcentaje_asistencia', 'salud_mental',
                 'nivel_estres', 'promedio_anterior', 'frecuencia_ejercicio', 'actividad_social','tiempo_pantalla','nivel_motivacion','nivel_ansiedad','gestion_tiempo','puntaje_examen']

df_habits[cols_to_round] = df_habits[cols_to_round].round(1)

# %%
#Pasamos a valores enteros del 1 al 10 los niveles de estres y salud mental para utilizarlos mejor en graficos
df_habits[['salud_mental','nivel_estres']] = df_habits[['salud_mental','nivel_estres']].round().astype(int)
df_habits[['salud_mental','nivel_estres']]
# Out:
#        salud_mental  nivel_estres
# 0                 6             6
# 1                 7             6
# 2                 6             8
# 3                 8             5
# 4                 9             6
# ...             ...           ...
# 79995             1             2
# 79996             6             4
# 79997             7             6
# 79998             8             2
# 79999             4             3
#
# [80000 rows x 2 columns]

# %% [markdown]
# ### 🧼 Limpieza y transformación de datos
#
# Una vez comprendida la estructura general del dataset, se procedió a realizar una limpieza y estandarización de los datos para prepararlos para el análisis:
#
# - 🔄 **Traducción de nombres de columnas** del inglés al español para mejorar la comprensión.
# - 🔁 **Traducción de valores categóricos** (por ejemplo, géneros, carreras, estilos de aprendizaje, niveles de calidad) para unificar el idioma en todo el análisis.
# - ✅ Se verificó la **ausencia de valores nulos y duplicados**, lo que permitió avanzar sin necesidad de imputación o depuración.
# - 🧪 Se revisaron los valores únicos de las columnas categóricas para asegurarse de que no hubiera datos mal ingresados o categorías innecesarias.
# - 🔢 Se **redondearon los valores numéricos** a una cifra decimal para facilitar las visualizaciones y análisis estadísticos.
# - 📊 Las variables **`salud_mental`** y **`nivel_estres`** fueron convertidas a enteros (de 1 a 10) para mejorar su tratamiento gráfico y analítico.
#
# Con estos pasos, se garantizó la homogeneidad y coherencia del dataset, dejándolo listo para la etapa de análisis exploratorio y modelado.

# %% [markdown]
# # 🎯 Hipótesis planteadas
#
#
# ## ⚠️ Hipótesis sobre el riesgo de deserción
#
# - A mayor puntaje de examen, menor riesgo de deserción.
# - El estilo de aprendizaje puede influir en el riesgo de deserción.
# - A mayor nivel de motivación, menor riesgo de deserción.
# - A mayor nivel de estrés, mayor riesgo de deserción.
# - A mayor nivel de salud mental, menor riesgo de deserción.
# - A mayor promedio anterior, menor riesgo de deserción.

# %% [markdown]
# ## 📊 Visualización de datos y Análisis Exploratorio (EDA)
# - Histogramas, boxplots, scatterplots
# - Relaciones entre variables
# - Comparaciones por categoría (género, carrera, dieta, etc.)

# %%
# A mayor puntaje de examen menos riesgo de desercion
sns.boxplot(data=df_habits, x='riesgo_desercion', y='puntaje_examen')
plt.title('Riesgo de desercion segun puntaje de examen')
plt.xlabel('Riesgo de Deserción')
plt.ylabel('Puntaje de Examen')
plt.show()

# %% [markdown]
# Los estudiantes con menor puntaje en los exámenes tienden a presentar un riesgo más alto de deserción académica. Como se observa en el gráfico, la mediana del puntaje es más baja en el grupo con riesgo, y la dispersión es mayor, indicando una mayor inestabilidad en el rendimiento académico de estos estudiantes.
#
# Este patrón sugiere que el rendimiento en evaluaciones formales puede estar estrechamente vinculado al compromiso con los estudios o a factores externos que afectan el desempeño. Por lo tanto, **el puntaje de examen surge como una variable clave** para anticipar posibles casos de abandono educativo.

# %%
#A mayor nivel de motivacion menos riesgo de desercion
sns.boxplot(data=df_habits, x='riesgo_desercion', y='nivel_motivacion')
plt.title('Riesgo de desercion segun nivel de motivacion')
plt.xlabel('Riesgo de Deserción')
plt.ylabel('Nivel de motivacion')
plt.show()

# %% [markdown]
# El análisis revela que los estudiantes que **no presentan riesgo de deserción** tienden a tener **niveles de motivación más altos**. La mediana de motivación en este grupo es notablemente superior, y la dispersión más acotada sugiere mayor estabilidad emocional y compromiso.
#
# En contraste, quienes están en riesgo muestran niveles de motivación más bajos y más variables, lo que puede reflejar inseguridad académica, desinterés o dificultad para sostener hábitos de estudio. Este comportamiento sugiere que la **motivación es un factor clave a considerar** al momento de identificar estudiantes vulnerables.

# %%
#A mayor nivel de estres mas riesgo de desercion
sns.boxplot(data=df_habits, x='riesgo_desercion', y='nivel_estres')
plt.title('Riesgo de desercion segun nivel de estres')
plt.xlabel('Riesgo de Deserción')
plt.ylabel('Nivel de estres')
plt.show()

# %% [markdown]
# Se observa una diferencia marcada entre los niveles de estrés de estudiantes con y sin riesgo de deserción académica. Aquellos que **presentan riesgo** tienen una **mediana de estrés considerablemente más alta**, concentrada entre valores de 7 a 9. En cambio, el grupo sin riesgo muestra niveles más bajos y dispersos, con una mediana cercana a 4.
#
# Este contraste sugiere que el **estrés elevado podría estar asociado al abandono académico**, ya sea como causa directa o como reflejo de otros factores problemáticos. La variable nivel_estres se posiciona como un indicador relevante dentro del modelo predictivo.

# %%
#A mayor nivel de salud mental menos riesgo de desercion
sns.boxplot(data=df_habits, x='riesgo_desercion', y='salud_mental')
plt.title('Riesgo de desercion segun nivel de salud mental')
plt.xlabel('Riesgo de Deserción')
plt.ylabel('Salud Mental')
plt.show()

# %% [markdown]
# El gráfico revela que los estudiantes **sin riesgo de deserción** tienden a tener **niveles de salud mental más altos**. La mediana del grupo “No” se sitúa en torno a valores más elevados y con menor dispersión, mientras que quienes presentan riesgo muestran una concentración en niveles más bajos, con mayor variabilidad.
#
# Este patrón sugiere que la **salud mental puede desempeñar un papel crítico en la permanencia académica**, ya sea como factor protector frente a la deserción o como indicador de posibles dificultades emocionales asociadas al abandono. Se destaca como una variable relevante tanto en el análisis descriptivo como en el modelado predictivo.

# %%
#A mayor promedio anterior menos riesgo de desercion
sns.boxplot(data=df_habits, x='riesgo_desercion', y='promedio_anterior')
plt.title('Riesgo de desercion segun promedio anterior')
plt.xlabel('Riesgo de Deserción')
plt.ylabel('Promedio anterior')
plt.show()

# %% [markdown]
# Los estudiantes sin riesgo de deserción presentan un **promedio anterior considerablemente más alto** en comparación con quienes sí están en riesgo. La mediana en el grupo “No” se sitúa en torno a 3,6, mientras que en el grupo “Sí” desciende por debajo de 3. Además, la dispersión de los datos es mayor entre los estudiantes con riesgo, lo que indica una mayor inestabilidad en el rendimiento previo.
#
# Este patrón evidencia que el desempeño académico sostenido en el tiempo puede funcionar como un **factor protector frente al abandono universitario**, y que el bajo rendimiento previo podría anticipar situaciones de deserción. Por ello, el promedio_anterior se consolida como una variable predictiva clave en el análisis.

# %%
# Que estilo de aprendizaje tiene mas riesgo de desercion
sns.boxplot(data=df_habits, x='riesgo_desercion', y='estilo_aprendizaje')
plt.title('Riesgo de desercion segun estilo de aprendizaje')
plt.xlabel('Riesgo de Deserción')
plt.ylabel('Estilo de aprendizaje')
plt.show()

# %% [markdown]
# El análisis sugiere que ciertos estilos de aprendizaje están ligeramente más asociados al riesgo de deserción académica. En particular, los estudiantes con estilo de aprendizaje **auditivo y kinestésico** muestran una mayor concentración en el grupo “Sí”, mientras que aquellos con estilo **visual o lector** se inclinan más hacia el grupo sin riesgo.
#
# Si bien la diferencia no es tan marcada como en otras variables analizadas, este comportamiento podría implicar que la forma en que se enfrentan los contenidos académicos influye en la permanencia. Adaptar las estrategias didácticas para integrar distintos estilos podría ser una vía interesante de prevención.

# %% [markdown]
# ## 💡 Insights obtenidos y evaluación de hipótesis
# - Qué se observa en los gráficos
# - Qué hipótesis se confirman parcialmente
# - Qué patrones relevantes aparecen

# %% [markdown]
# ### ⚠️ Riesgo de Deserción
#
# 1. **Puntaje de examen**
#    Los estudiantes con menor puntaje en los exámenes presentan un mayor riesgo de deserción, lo que los convierte en un grupo prioritario para intervenciones.
#
# 2. **Motivación**
#    Se observa una relación inversa: a menor motivación, mayor riesgo de abandonar los estudios.
#
# 3. **Estrés**
#    Niveles altos de estrés están asociados a un mayor riesgo de deserción, lo cual pone en evidencia la importancia del acompañamiento emocional.
#
# 4. **Salud mental**
#    Un mal estado de salud mental se relaciona con un aumento en el riesgo de abandono escolar, mostrando la necesidad de estrategias de apoyo psicológico.
#
# 5. **Promedio académico previo**
#    Estudiantes con bajo desempeño previo tienen mayor probabilidad de desertar, lo que sugiere que necesitan un seguimiento más cercano.
#
# 6. **Estilo de aprendizaje**
#    El análisis del estilo de aprendizaje muestra diferencias interesantes:
#    - En estudiantes con **alto riesgo de deserción**, el estilo más común es el **auditivo** y menos frecuente la lectura.
#    - En cambio, entre quienes tienen **bajo riesgo**, predominan los estilos **kinestésico** y **lectura**.
#    Esto puede indicar que ciertos estilos de aprendizaje están menos adaptados al entorno educativo actual y podrían necesitar ajustes metodológicos.
#
# ---

# %% [markdown]
# # 🧠 Selección de variables relevantes

# %%
#Elegimos variables
variables_utiles = [
    'nivel_motivacion',
    'nivel_estres',
    'salud_mental',
    'puntaje_examen',
    'promedio_anterior',
]
#Hacemos un df nuevo acortado
df_modelo = df_habits[variables_utiles + ['riesgo_desercion']].copy()
#Pasamos los si y no a 1 y 0
df_modelo['riesgo_desercion'] = df_modelo['riesgo_desercion'].map({'Si': 1, 'No': 0})

# %%
# Importamos las herramientas para escalado y selección de características
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif

# Separamos las variables predictoras (X1) de la variable objetivo (y1)
X1 = df_modelo.drop("riesgo_desercion", axis=1)
y1 = df_modelo["riesgo_desercion"]

# Escalamos las variables predictoras para normalizarlas
scaler1 = StandardScaler()
X1_scaled = scaler1.fit_transform(X1)

# Seleccionamos las 3 variables más relevantes según ANOVA F-test
selector1 = SelectKBest(score_func=f_classif, k=3)
X1_selected = selector1.fit_transform(X1_scaled, y1)

# Obtenemos los nombres de las variables seleccionadas
selected_mask1 = selector1.get_support()
selected_features1 = [f for f, s in zip(X1.columns, selected_mask1) if s]
print("Variables seleccionadas desde df_modelo:", selected_features1)
# Out:
# Variables seleccionadas desde df_modelo: ['nivel_motivacion', 'nivel_estres', 'promedio_anterior']

# %% [markdown]
# ### 🧠 Modelado y evaluación
#
# Para abordar el problema de predicción del riesgo de deserción, se implementaron y compararon dos modelos supervisados de clasificación:

# %% [markdown]
# #### 📍 1. Regresión Logístic

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Definir variables y target
X = df_modelo[selected_features1]
y = df_modelo["riesgo_desercion"]

# Dividimos en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo
modelo_logit = LogisticRegression()
modelo_logit.fit(X_train, y_train)

# Predicción y evaluación
y_pred = modelo_logit.predict(X_test)


print("📊 LogisticRegression - Reporte de Clasificación:")
print(classification_report(y_test, y_pred))
print("📉 Matriz de Confusión:")
print(confusion_matrix(y_test, y_pred))
# Out:
# 📊 LogisticRegression - Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     23549
#            1       0.67      0.65      0.66       451
#
#     accuracy                           0.99     24000
#    macro avg       0.83      0.82      0.83     24000
# weighted avg       0.99      0.99      0.99     24000
#
# 📉 Matriz de Confusión:
# [[23401   148]
#  [  157   294]]

# %% [markdown]
# #### 🌳 2. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Variables seleccionadas
X = df_modelo[["nivel_motivacion", "nivel_estres", "promedio_anterior"]]
y = df_modelo["riesgo_desercion"]

# Escalado
preprocessor = ColumnTransformer(
    transformers=[("num", StandardScaler(), X.columns)],
    remainder="passthrough"
)

# Pipeline con Random Forest
rf_model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(n_estimators=100, random_state=42))
])

# Separación de datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamiento
rf_model.fit(X_train, y_train)


# Predicción y métricas
y_pred_rf = rf_model.predict(X_test)

print("📊 Random Forest - Reporte de Clasificación:")
print(classification_report(y_test, y_pred_rf))
print("📉 Matriz de Confusión:")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# 📊 Random Forest - Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     23549
#            1       0.91      0.63      0.75       451
#
#     accuracy                           0.99     24000
#    macro avg       0.95      0.82      0.87     24000
# weighted avg       0.99      0.99      0.99     24000
#
# 📉 Matriz de Confusión:
# [[23522    27]
#  [  166   285]]

# %% [markdown]
# #### ⚡ 3. Support Vector Machines (SVM)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

#Variable binaria
x = df_modelo[selected_features1]
y = df_modelo["riesgo_desercion"]

#Escalar datos
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# Dividimos en train y test
x_train, x_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Entrenamos el modelo
svm = SVC(kernel='rbf', class_weight='balanced')
svm.fit(x_train, y_train)

# Predicción y métricas
y_pred = svm.predict(x_test)

#Predicción y métricas
print("⚡Support Vector Machine - Reporte de Clasificación:")
print(classification_report(y_test, y_pred))
print("📉 Matriz de Confusión:")
print(confusion_matrix(y_test, y_pred))

# Visualizar
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# ⚡Support Vector Machine - Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     23549
#            1       0.57      1.00      0.72       451
#
#     accuracy                           0.99     24000
#    macro avg       0.78      0.99      0.86     24000
# weighted avg       0.99      0.99      0.99     24000
#
# 📉 Matriz de Confusión:
# [[23206   343]
#  [    0   451]]

# %% [markdown]
# ## 📌 Conclusiones del Modelo
#
#
# Se entrenaron dos modelos supervisados para predecir el **riesgo de deserción académica** a partir de las variables seleccionadas automáticamente mediante *SelectKBest*:
# **nivel_motivación**, **nivel_estrés** y **promedio_anterior**.
#
# ### 📍 Regresión Logística:
# - Mostró un **desempeño general muy alto** (accuracy del 99%).
# - Obtuvo un **recall del 65%** en la clase positiva (deserción), lo que indica una **capacidad moderada para detectar estudiantes en riesgo**.
# - Aunque sencillo e interpretable, **no logró identificar con tanta precisión todos los casos positivos**.
#
# ### 🌳 Random Forest:
# - También alcanzó un **accuracy del 99%**, pero con mejores resultados en la clase positiva.
# - Logró una **precisión del 91%** en la detección de casos de deserción, con un **F1-score superior al de la regresión logística**.
# - Si bien el *recall* fue levemente menor (63%), **cometió menos errores al clasificar como "riesgo" a quienes no lo eran**.
#
# ### ⚡ Support Vector Machine (SVM RBF):
# Entrenar el SVM con kernel RBF permitió capturar relaciones no lineales entre las variables.
# Obtuvo un recall del 100% en la clase positiva, lo que significa que ningún estudiante en riesgo quedó sin identificar, aunque la precisión fue menor (57%), generando más falsos positivos.
# El F1-score de 0.72 refleja un equilibrio razonable entre capacidad de detección y exactitud.
#
# ### 🔹 Conclusión general:
# Los tres modelos fueron efectivos, pero cada uno tiene ventajas según el objetivo:
#
# SVM RBF: ideal como alarma temprana, asegurando que no se escape ningún caso de deserción.
#
# Random Forest: mejor para alertas confiables, minimizando falsos positivos.
#
# Regresión Logística: útil como modelo explicativo y referencia por su simplicidad.
#
# En conjunto, se recomienda utilizar SVM para detección temprana y Random Forest para priorización de casos, garantizando tanto sensibilidad como confiabilidad en la predicción de deserción estudiantil.

# %% [markdown]
# #### 🧠 4. PCA (Principal Component Analysis)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Aplicar PCA a las variables seleccionadas
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Crear DataFrame para graficar
df_pca = pd.DataFrame(X_pca, columns=["Componente 1", "Componente 2"])
df_pca["riesgo_desercion"] = y.values

# Scatter plot
plt.figure(figsize=(8,6))
for clase in [0, 1]:
    subset = df_pca[df_pca["riesgo_desercion"] == clase]
    plt.scatter(subset["Componente 1"], subset["Componente 2"],
                label=f"Deserción: {clase}", alpha=0.7)

plt.title("Distribución PCA según riesgo de deserción")
plt.xlabel("Componente Principal 1")
plt.ylabel("Componente Principal 2")
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 🌀 Interpretación del PCA
#
# El gráfico de PCA permite observar la distribución de los estudiantes en un espacio reducido a partir de las variables seleccionadas (**nivel_motivación**, **nivel_estrés** y **promedio_anterior**).
#
# Aunque existe cierta superposición entre clases (lo cual es esperable), se distinguen zonas del plano donde los estudiantes con riesgo de deserción tienden a agruparse, lo que indica que **estas variables aportan información relevante para detectar posibles casos de deserción**.
#
# Esta visualización refuerza la utilidad de la selección de variables aplicada y ayuda a comprender visualmente los patrones detrás del modelo de clasificación.

# %% [markdown]
# ## 📌 Conclusiones finales
#
# En este proyecto analizamos los factores que influyen en el riesgo de deserción de estudiantes universitarios, utilizando un enfoque basado en datos. A partir del análisis exploratorio inicial, se identificaron varias variables con cierto nivel de correlación negativa con el riesgo de deserción, destacándose principalmente:
#
# 🔹 Nivel de motivación: los estudiantes con mayor motivación presentan significativamente menor riesgo de abandonar sus estudios.
#
# 🔹 Nivel de estrés: a menor nivel de estrés, menor riesgo de deserción, lo que sugiere que el manejo emocional influye en la permanencia académica.
#
# 🔹 Promedio académico anterior: un mejor rendimiento previo se asocia con menor probabilidad de abandonar la carrera.
#
# Estas tres variables fueron seleccionadas mediante el método de SelectKBest como las más relevantes para entrenar los modelos predictivos de clasificación.
#
# Se entrenaron tres modelos supervisados para predecir el riesgo de deserción:
#
# 📍 Regresión Logística: mostró un desempeño general muy alto (accuracy del 99%) y permite interpretar fácilmente el impacto de cada variable, aunque no logra detectar todos los casos de deserción (recall 65%).
#
# 🌳 Random Forest: también alcanzó un accuracy del 99%, con alta precisión en la clase positiva (91%) y un F1-score superior al de la regresión logística, lo que lo hace útil para alertas confiables.
#
# ⚡ Support Vector Machine (SVM RBF): capturó relaciones no lineales entre las variables, logrando un recall del 100%, lo que garantiza que no se escape ningún estudiante en riesgo, aunque presenta más falsos positivos (precisión 57%), funcionando como un sistema de alarma temprana.
#
# #### Conclusión integradora:
#
# El uso conjunto de estos modelos permite equilibrar sensibilidad y confiabilidad en la predicción del riesgo de deserción. Se recomienda emplear SVM RBF para detección temprana de todos los casos posibles, y Random Forest para priorizar los casos con mayor certeza, complementando así la intervención educativa.
#
# El proyecto demuestra que, a partir de variables simples y fácilmente medibles, es posible desarrollar un sistema predictivo efectivo que sirva como herramienta para la retención estudiantil y la toma de decisiones educativas.
